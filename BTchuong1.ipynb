# %%
#Bai 1
n = int(input("nhap so n"))
def ham(n):
    return n*2
print(ham(n))
# Out:
# 6

# %%
#Bai 2
a = int(input("nhap so a"))
b = int(input("nhap so b"))
def ham(a,b):
    return a*b-3.14*(a*a)/4
print(ham(a,b))
# Out:
# 7.935

# %%
#Bai 3
x = input()
if x =="c":
    print("C")
else:
    print("c")
# Out:
# C

# %%
#Bai 4
c = input()
if c.isalpha():
   print("{c} la ki tu alphabet")
else:
   print("{c} khong phai la ki tu alphabet")
# Out:
# {c} khong phai la ki tu alphabet

# %%
#Bai 5
x = input("Nhap vao chu cai hoa")
if x == "A":
    print("z")
elif 'B' <= x <= 'Z':
     ketqua = chr(ord(x)+32-1)
     print(ketqua)
# Out:
# z

# %%
#Bai 6
a,b,c = map(int,input().split())
if a+b > c and b+c > a and c+a > b:
   p = (a+b+c)/2
   S = (p*(p-a)*(p-b)*(p-c))**0.5
   print(S)
else:
   print("Khong phai 3 canh cua tam giac")
# Out:
# 6.0

# %%
#Bai 7
s = input()
if len(s) >= 20:
   thu5 = s[4]
   thu9 = s[8]
   print(thu5)
   print(thu9)
else:
    print("nhap tren 20 ki tu")
# Out:
# nhap tren 20 ki tu

# %%
#Bai 8
x = input()
if x == "Pham Xuan Toai":
    print("Ten chu ho: Pham Xuan Toai")
    print("Chi so thang truoc: 1020")
    print("Chi so thang nay: 1070")
    print("Tien phai tra la: 107136")
elif x == "Nguyen Xuan Long":
    print("Ten chu ho: Nguyen Xuan Long")
    print("Chi so thang truoc: 2090")
    print("Chi so thang nay: 2278")
    print("Tien phai tra la: 426038")
elif x == "Nguyen Xuan Hai":
    print("Ten chu ho: Nguyen Xuan Hai")
    print("Chi so thang truoc: 2000")
    print("Chi so thang nay: 2586")
    print("Tien phai tra la: 1855505")
# Out:
# Ten chu ho: Nguyen Xuan Hai
# Chi so thang truoc: 2000
# Chi so thang nay: 2586
# Tien phai tra la: 1855505

# %%
#Bai 1
x = int(input())
if x % 2 == 0:
    print("so chan")
else:
    print("so le")
# Out:
# so chan

# %%
#Bai 2
x = int(input())
if x % 10 == 0 or x % 5 != 0:
   print("False")
elif x % 5 == 0:
    print("True")
# Out:
# False

# %%
#Bai 3
x = int(input())
if x % 5 == 0 and x % 3 == 0:
   print("True")
else:
    print("False")
# Out:
# True

# %%
#Bai 4
x = int(input())
if x < 18:
    print("khong du dieu kien")
else:
    print("du dieu kien")
# Out:
# du dieu kien

# %%
#Bai 5
a = float(input())
b = float(input())
if a == b:
    print("hai so bang nhau")
elif a > b:
    print(a)
else:
    print(b)
# Out:
# hai so bang nhau

# %%
#Bai 6
x = input()
if x.isalpha():
    print("chu cai")
else:
    print("so")
# Out:
# chu cai

# %%
#Bai 7
x = float(input())
if x >= 8:
    print("Gioi")
elif 6.5 <= x < 8:
    print("Kha")
elif 5 <= x < 6.5:
    print("Trung binh")
elif x < 5:
    print("Yeu")
# Out:
# Trung binh

# %%
#Bai 8
x = int(input())
if x % 400 == 0:
    print("Nam nhuan")
elif x % 4 == 0 and x % 100 != 0:
    print("Nam nhuan")
else:
    print("Khong phai nam nhuan")
# Out:
# Nam nhuan

# %%
#Bai 9
n = int(input())
match n:
    case 0:
        print("Khong")
    case 1:
        print("Mot")
    case 2:
        print("Hai")
    case 3:
        print("Ba")
    case 4:
        print("Bon")
    case 5:
        print("Nam")
    case 6:
        print("Sau")
    case 7:
        print("Bay")
    case 8:
        print("Tam")
    case 9:
        print("Chin")
# Out:
# Mot

# %%
#Bai 10
x = float(input())
if x >= 4:
   print("Qua mon")
else:
    print("Hoc lai")
# Out:
# Qua mon

# %%
#Bai 11
x = int(input())
if 2026-x >= 18:
    print("Du tuoi")
else:
    print("Chua du tuoi")
# Out:
# Du tuoi
